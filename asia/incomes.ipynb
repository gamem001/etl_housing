# %%
import pandas as pd
import numpy as np
from sqlalchemy import engine
# from config import password

# %%
csv = pd.read_csv('median_income_data.csv')
csv
# Out:
#     Table with row headers in column A and column headers in rows 5 and 6, and 60 and 61  \
# 0    Table H-8.  Median Household Income by State: ...
# 1    (Households as of March of the following year....
# 2                                      CURRENT DOLLARS
# 3                                                State
# 4                                                  NaN
# ..                                                 ...
# 110                                          Wisconsin
# 111                                            Wyoming
# 112  Source: U.S. Bureau of the Census, Current Pop...
# 113  Footnotes are available at <www.census.gov/top...
# 114                                                NaN
#
#          Unnamed: 1       Unnamed: 2      Unnamed: 3       Unnamed: 4  \
# 0               NaN              NaN             NaN              NaN
# 1               NaN              NaN             NaN              NaN
# ...

# %%
# This is how I knew which rows were specifically for Florida

# florida = csv.loc[csv['Table with row headers in column A and column headers in rows 5 and 6, and 60 and 61'] == 'Florida']
# florida

# %%
csv_florida = csv.iloc[[3, 4, 15, 70], :]
csv_florida
# Out:
#    Table with row headers in column A and column headers in rows 5 and 6, and 60 and 61  \
# 3                                               State
# 4                                                 NaN
# 15                                            Florida
# 70                                            Florida
#
#         Unnamed: 1       Unnamed: 2      Unnamed: 3       Unnamed: 4  \
# 3             2018              NaN       2017 (40)              NaN
# 4   Median\nincome  Standard\nerror  Median\nincome  Standard\nerror
# 15          54,644            1,887          53,086            1,438
# 70          54,644            1,887          54,380            1,473
#
#         Unnamed: 5       Unnamed: 6      Unnamed: 7       Unnamed: 8  \
# 3             2017              NaN            2016              NaN
# 4   Median\nincome  Standard\nerror  Median\nincome  Standard\nerror
# 15          53,681            1,816          51,176              835
# ...

# %%
# fl_homeless_new = csv_florida.transpose()
# fl_homeless_new

fl_homeless_new = csv_florida.T.reset_index(); 
fl_income_table = fl_homeless_new[fl_homeless_new.columns[::-1]]
fl_income_table
# Out:
#          70       15                4          3  \
# 0   Florida  Florida              NaN      State
# 1    54,644   54,644   Median\nincome       2018
# 2     1,887    1,887  Standard\nerror        NaN
# 3    54,380   53,086   Median\nincome  2017 (40)
# 4     1,473    1,438  Standard\nerror        NaN
# ..      ...      ...              ...        ...
# 70    1,184      540  Standard\nerror        NaN
# 71   47,632   21,343   Median\nincome  1985 (20)
# 72      975      437  Standard\nerror        NaN
# 73   45,671   19,785   Median\nincome  1984 (19)
# 74    1,080      468  Standard\nerror        NaN
#
#                                                 index
# 0   Table with row headers in column A and column ...
# 1                                          Unnamed: 1
# 2                                          Unnamed: 2
# 3                                          Unnamed: 3
# 4                                          Unnamed: 4
# ...

# %%
arbitrary = fl_income_table.drop(columns =['index'])
arbitrary
# Out:
#          70       15               4          3
# 0   Florida  Florida              NaN      State
# 1    54,644   54,644   Median\nincome       2018
# 2     1,887    1,887  Standard\nerror        NaN
# 3    54,380   53,086   Median\nincome  2017 (40)
# 4     1,473    1,438  Standard\nerror        NaN
# ..      ...      ...              ...        ...
# 70    1,184      540  Standard\nerror        NaN
# 71   47,632   21,343   Median\nincome  1985 (20)
# 72      975      437  Standard\nerror        NaN
# 73   45,671   19,785   Median\nincome  1984 (19)
# 74    1,080      468  Standard\nerror        NaN
#
# [75 rows x 4 columns]

# %%
# arbitrary.to_csv('florida_income_csv_cleaning', index=False)

# %%
dirty_csv = pd.read_csv('florida_income_csv_cleaning')
dirty_csv
# Out:
#    Florida_Too    State    Median_Income    Florida
# 0      Florida  Florida              NaN      State
# 1       54,644   54,644   Median\nincome       2018
# 2        1,887    1,887  Standard\nerror        NaN
# 3       54,380   53,086   Median\nincome  2017 (40)
# 4        1,473    1,438  Standard\nerror        NaN
# ..         ...      ...              ...        ...
# 70       1,184      540  Standard\nerror        NaN
# 71      47,632   21,343   Median\nincome  1985 (20)
# 72         975      437  Standard\nerror        NaN
# 73      45,671   19,785   Median\nincome  1984 (19)
# 74       1,080      468  Standard\nerror        NaN
#
# [75 rows x 4 columns]

# %%
dirty_csv.rename(columns = {'Florida_Too': 'Florida', 'State': 'Florida_Too', 'Median_Income': 'Median_Income', 'Florida': 'Year'}, inplace = True)
dirty_csv
dirty_csv.to_csv('final_median_income_csv', index=False)

# %%
clean_csv = pd.read_csv('final_median_income_csv')
clean_csv
# Out:
#     Florida Florida_Too    Median_Income       Year
# 0   Florida     Florida              NaN      State
# 1    54,644      54,644   Median\nincome       2018
# 2     1,887       1,887  Standard\nerror        NaN
# 3    54,380      53,086   Median\nincome  2017 (40)
# 4     1,473       1,438  Standard\nerror        NaN
# ..      ...         ...              ...        ...
# 70    1,184         540  Standard\nerror        NaN
# 71   47,632      21,343   Median\nincome  1985 (20)
# 72      975         437  Standard\nerror        NaN
# 73   45,671      19,785   Median\nincome  1984 (19)
# 74    1,080         468  Standard\nerror        NaN
#
# [75 rows x 4 columns]

# %%
clean_csv.drop([0, 0])
clean_csv
# Out:
#     Florida Florida_Too    Median_Income       Year
# 0   Florida     Florida              NaN      State
# 1    54,644      54,644   Median\nincome       2018
# 2     1,887       1,887  Standard\nerror        NaN
# 3    54,380      53,086   Median\nincome  2017 (40)
# 4     1,473       1,438  Standard\nerror        NaN
# ..      ...         ...              ...        ...
# 70    1,184         540  Standard\nerror        NaN
# 71   47,632      21,343   Median\nincome  1985 (20)
# 72      975         437  Standard\nerror        NaN
# 73   45,671      19,785   Median\nincome  1984 (19)
# 74    1,080         468  Standard\nerror        NaN
#
# [75 rows x 4 columns]

# %%
postgres_conn_string = f"postgres:{password}" 
engine = create_engine(f"postgresql://{postgres_conn_string}@localhost:5432/etl_database")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-2adbe8647a7c> in <module>
# ----> 1 postgres_conn_string = f"postgres:{password}"
#       2 engine = create_engine(f"postgresql://{postgres_conn_string}@localhost:5432/etl_database")
#
# NameError: name 'password' is not defined
